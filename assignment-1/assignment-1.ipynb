# %% [markdown]
# # Assignment 1 - Python for Data Science
#
# Objective:
#
# The purpose of this assignment is to ensure that you are comfortable with Python programming and basic data manipulation using the Pandas library. By the end of this assignment, you should be able to:
#
# * Understand Python basics: variables, data types, control structures, functions, and data structures.
# * Perform basic data manipulation and exploration using Pandas.
# * Read, filter, sort, and analyze data in a DataFrame.
#
#
# Instructions:
#
# Complete each of the tasks below. Download and upload your Jupyter notebook containing your code **and output** along with all answers to your github classroom repository. Add, commit, and push the notebook before the due date.

# %%
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Part 1: Python Basics (10 points)
#
# Variables and Data Types:
#
# Define a variable x as the sum of 5 and 10.
#
# Print the data type of x.

# %%
# YOUR CODE HERE
x = 5 + 10
print(type(x))
# Out:
# <class 'int'>

# %% [markdown]
# Control Structures:
#
# Write a Python function that takes a list of numbers and returns a list of only the even numbers.

# %%
# YOUR CODE HERE
def getEvenNum(numList):
  evenList = []
  for x in numList:
    if x % 2 == 0:
      evenList.append(x)
  return evenList

# %% [markdown]
# Functions:
#
# Create a function that takes two arguments (length and width) and returns the area of a rectangle.
# python

# %%
# YOUR CODE HERE
def areaRect(length, width):
  return length * width

# %% [markdown]
# ## Part 2: Introduction to Pandas (55 points)
#
# For this assignment you'll be working with the Iris dataset. Read more about the Iris dataset [here](https://www.kaggle.com/datasets/vikrishnan/iris-dataset?resource=download). Your data for this assignment is in iris_data.csv. You may need to read more about the dataset in order to map the variables in the data.

# %% [markdown]
# **Question: What is the Iris dataset?**
#
# YOUR ANSWER: The Iris dataset is a multivariable dataset containing 50 samples from each of the three species of Iris with four features measured from each sample.

# %% [markdown]
# Read in the csv file using [DataFrame.read_csv()](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html)

# %%
# YOUR CODE HERE
headers = ["Sepal Length (cm)", "Sepal Width (cm)", "Petal Length (cm)", "Petal Width (cm)", "Iris Species"]
df = pd.read_csv("/content/drive/My Drive/CoLab Notebooks/ODSA_Machine_Learning/Datasets/iris.data.csv", names=headers)

# %% [markdown]
# Look at the first 5 records in the dataset us [DataFrame.head](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html) and and validate that the proper headers were applied with the read_csv function

# %%
# YOUR CODE HERE
df.head()
# Out:
#    Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   Iris Species
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %% [markdown]
# **Question: How many records are in the dataset?**
#
# YOUR ANSWER: There are 150 records in the dataset.

# %%
# YOUR CODE HERE
len(df)
# Out:
# 150

# %% [markdown]
# **Question: How many features are there?**
#
# YOUR ANSWER: There are 4 features in the dataset

# %%
# YOUR CODE HERE
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sepal Length (cm)  150 non-null    float64
#  1   Sepal Width (cm)   150 non-null    float64
#  2   Petal Length (cm)  150 non-null    float64
#  3   Petal Width (cm)   150 non-null    float64
#  4   Iris Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# **Question: What is the unit of measurement?**
#
# YOUR ANSWER: The unit of measurement for the records is centimeters

# %% [markdown]
# **Question: What is the target variable?**
#
# YOUR ANSWER: The target variable of the records is the species of the Iris flower

# %%
# YOUR CODE HERE
df.columns
# Out:
# Index(['Sepal Length (cm)', 'Sepal Width (cm)', 'Petal Length (cm)',
#        'Petal Width (cm)', 'Iris Species'],
#       dtype='object')

# %% [markdown]
# **Question: What type of machine learning problem is this?**
#
# YOUR ANSWER: The machine learning problem is a supervised learning problem.

# %% [markdown]
# **Question: How many species are in each class? Is this a well separated dataset?**
#
# YOUR ANSWER: There are three species in each class, and the Iris dataset is a well separated dataset.

# %% [markdown]
# **Question: Are there any null values in the data?**
#
# YOUR ANSWER: There are no null values in the dataset for any of the features or for the target

# %%
df['Iris Species'].value_counts()
# Out:
# Iris Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
# YOUR CODE HERE
df.isnull().sum()
# Out:
# Sepal Length (cm)    0
# Sepal Width (cm)     0
# Petal Length (cm)    0
# Petal Width (cm)     0
# Iris Species         0
# dtype: int64

# %% [markdown]
# Run [DataFrame.describe](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html).
#
# **Question: What is the max value of pedal width? What is the min value of sepal length?**
#
# YOUR ANSWER: The max value of pedal width is 2.5 centimeters. The min value of sepal length is 4.3 centimeters.

# %%
df.describe()
# Out:
#        Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.054000           3.758667
# std             0.828066          0.433594           1.764420
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        Petal Width (cm)
# count        150.000000
# mean           1.198667
# std            0.763161
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# Filtering and Sorting Data:
#
# Filter the DataFrame to show only rows where the species is versicolor.
#
# Sort the DataFrame by the column "SepalWidthCm" in ascending order.

# %%
# YOUR CODE HERE
df.query('`Iris Species`=="Iris-versicolor"')
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
# 55                5.7               2.8                4.5               1.3
# 56                6.3               3.3                4.7               1.6
# 57                4.9               2.4                3.3               1.0
# 58                6.6               2.9                4.6               1.3
# 59                5.2               2.7                3.9               1.4
# 60                5.0               2.0                3.5               1.0
# 61                5.9               3.0                4.2               1.5
# 62                6.0               2.2                4.0               1.0
# 63                6.1               2.9                4.7               1.4
# 64                5.6               2.9                3.6               1.3
# 65                6.7               3.1                4.4               1.4
# 66                5.6               3.0                4.5               1.5
# 67                5.8               2.7                4.1               1.0
# 68                6.2               2.2                4.5               1.5
# 69                5.6               2.5                3.9               1.1
# 70                5.9               3.2                4.8               1.8
# 71                6.1               2.8                4.0               1.3
# 72                6.3               2.5                4.9               1.5
# 73                6.1               2.8                4.7               1.2
# 74                6.4               2.9                4.3               1.3
# 75                6.6               3.0                4.4               1.4
# 76                6.8               2.8                4.8               1.4
# 77                6.7               3.0                5.0               1.7
# 78                6.0               2.9                4.5               1.5
# 79                5.7               2.6                3.5               1.0
# 80                5.5               2.4                3.8               1.1
# 81                5.5               2.4                3.7               1.0
# 82                5.8               2.7                3.9               1.2
# 83                6.0               2.7                5.1               1.6
# 84                5.4               3.0                4.5               1.5
# 85                6.0               3.4                4.5               1.6
# 86                6.7               3.1                4.7               1.5
# 87                6.3               2.3                4.4               1.3
# 88                5.6               3.0                4.1               1.3
# 89                5.5               2.5                4.0               1.3
# 90                5.5               2.6                4.4               1.2
# 91                6.1               3.0                4.6               1.4
# 92                5.8               2.6                4.0               1.2
# 93                5.0               2.3                3.3               1.0
# 94                5.6               2.7                4.2               1.3
# 95                5.7               3.0                4.2               1.2
# 96                5.7               2.9                4.2               1.3
# 97                6.2               2.9                4.3               1.3
# 98                5.1               2.5                3.0               1.1
# 99                5.7               2.8                4.1               1.3
#
#        Iris Species
# 50  Iris-versicolor
# 51  Iris-versicolor
# 52  Iris-versicolor
# 53  Iris-versicolor
# 54  Iris-versicolor
# 55  Iris-versicolor
# 56  Iris-versicolor
# 57  Iris-versicolor
# 58  Iris-versicolor
# 59  Iris-versicolor
# 60  Iris-versicolor
# 61  Iris-versicolor
# 62  Iris-versicolor
# 63  Iris-versicolor
# 64  Iris-versicolor
# 65  Iris-versicolor
# 66  Iris-versicolor
# 67  Iris-versicolor
# 68  Iris-versicolor
# 69  Iris-versicolor
# 70  Iris-versicolor
# 71  Iris-versicolor
# 72  Iris-versicolor
# 73  Iris-versicolor
# 74  Iris-versicolor
# 75  Iris-versicolor
# 76  Iris-versicolor
# 77  Iris-versicolor
# 78  Iris-versicolor
# 79  Iris-versicolor
# 80  Iris-versicolor
# 81  Iris-versicolor
# 82  Iris-versicolor
# 83  Iris-versicolor
# 84  Iris-versicolor
# 85  Iris-versicolor
# 86  Iris-versicolor
# 87  Iris-versicolor
# 88  Iris-versicolor
# 89  Iris-versicolor
# 90  Iris-versicolor
# 91  Iris-versicolor
# 92  Iris-versicolor
# 93  Iris-versicolor
# 94  Iris-versicolor
# 95  Iris-versicolor
# 96  Iris-versicolor
# 97  Iris-versicolor
# 98  Iris-versicolor
# 99  Iris-versicolor

# %%
# YOUR CODE HERE
df.sort_values(by=['Sepal Width (cm)'])
# Out:
#      Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# 60                 5.0               2.0                3.5               1.0
# 62                 6.0               2.2                4.0               1.0
# 119                6.0               2.2                5.0               1.5
# 68                 6.2               2.2                4.5               1.5
# 41                 4.5               2.3                1.3               0.3
# ..                 ...               ...                ...               ...
# 16                 5.4               3.9                1.3               0.4
# 14                 5.8               4.0                1.2               0.2
# 32                 5.2               4.1                1.5               0.1
# 33                 5.5               4.2                1.4               0.2
# 15                 5.7               4.4                1.5               0.4
#
#         Iris Species
# 60   Iris-versicolor
# 62   Iris-versicolor
# 119   Iris-virginica
# 68   Iris-versicolor
# 41       Iris-setosa
# ..               ...
# 16       Iris-setosa
# 14       Iris-setosa
# 32       Iris-setosa
# 33       Iris-setosa
# 15       Iris-setosa
#
# [150 rows x 5 columns]

# %% [markdown]
# Plotting a dataset is a great way to explore its distribution. Plotting the iris dataset can be done using matplotlib, a Python library for 2D plotting.

# %%
# YOUR CODE HERE
import matplotlib.pyplot as plt
colors=['red','orange','blue']
species=['Iris-virginica','Iris-versicolor','Iris-setosa']
for i in range(3):
    x=df[df['Iris Species']==species[i]]
    plt.scatter(x['Sepal Length (cm)'],x['Sepal Width (cm)'],c= colors[i],label=species[i])

plt.xlabel("Sepal Length")
plt.ylabel("sepal width")
plt.legend()

# %% [markdown]
# **Question: What are your thoughts on how we might measure success on this problem (i.e. a model that predicts the target labels)?**
#
# YOUR ANSWER: We might measure success on predicting the target labels using linear regression with a combination of the sepal width and length as the plot shows each iris species has their own best fit line.

# %% [markdown]
# ---
# ## Part 3: Supervised Learning
# Supervised learning is all about learning to make predictions: given an input $x$ (e.g. home square footage), can we produce an output $\hat{y}$ (e.g. estimated value) as close to the actual observed output $y$ (e.g. sale price) as possible. Note that the "hat" above $y$ is used to denote an estimated or predicted value.
#
# Let's start by generating some artificial data. We'll create a vector of inputs, $X$, and a corresponding vector of target outputs $Y$. In general, we'll refer to invidual examples with a lowercase ($x$), and a vector or matrix containing multiple examples with a capital ($X$).

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Generating a Known Function (15 points)
#
# Implement variable Y as:
#
# $Y = m*X + b + variance$

# %%
def create_1d_data(num_examples=10, m=2, b=1, random_scale=1):
    """Create X, Y data with a linear relationship with added noise.

    Args:
    num_examples: number of examples to generate
    w: desired slope
    b: desired intercept
    random_scale: add uniform noise between -random_scale and +random_scale

    Returns:
    X and Y with shape (num_examples)
    """
    X = np.arange(num_examples)
    np.random.seed(4)  # consistent random number generation
    random_variance = np.random.uniform(low=-random_scale, high=random_scale, size=X.shape)
    # TODO: build Y = mx + b + random_variance
    Y = m * X + b + random_variance

    return X, Y

# %%
# Create some artificial data using create_1d_data.
X, Y = create_1d_data()
plt.scatter(X, Y)
plt.show()

# %% [markdown]
# **Question: Explain why the graph does not exactly represent 2X+1**
#
# YOUR ANSWER: The graph does not exactly represent 2X+1 as it includes the random variance which accounts for uniform noise

# %% [markdown]
# ## Models for Data (15 points)

# %% [markdown]
# A model is a function that takes an input $x$ and produces a prediction $\hat{y}$.
#
# Let's consider two possible models for this data:
# 1. $M_1(x) = x+5$
# 2. $M_2(x) = 2x+1$
#
# Compute the predictions of models $M_1$ and $M_2$ for the values in $X$. These predictions should be vectors of the same shape as $Y$. Then plot the prediction lines of these two models overlayed on the "observed" data $(X, Y)$. Use [plt.plot()](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html) to draw the lines. Note: you will generate only one plot. Make sure to include axes, titles and legend.

# %%
# YOUR CODE HERE
M1 = X + 5
M2 = 2 * X + 1

# %%
plt.scatter(X, Y)

plt.plot(M1, color = 'r')
plt.plot(M2, color = 'g')

plt.legend(["X Observed Data", "M1 Model Preds", "M2 Model Preds"], loc="lower right")

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Comparison of M1 and M2 Models", fontdict = font1)
plt.xlabel("X Input Values", fontdict = font2)
plt.ylabel("Y Output Values", fontdict = font2)

plt.show()

# %% [markdown]
# **Question: Explain which model looks to be performing better. How do you know?**
#
# YOUR ANSWER: The M2 model appears to be performing better and I know this as the M2 prediction line fits the observed data better than the M1 prediction line.

# %% [markdown]
# ---

# %% [markdown]
# ## Review
#
# * In **Supervised Machine Learning**, we must start with data in the form $(X,Y)$ where $X$ are the inputs and $Y$ are the output labels.
# * A **model** is a function that maps an input $x$ to an output $y$. The model's output is referred to as a **prediction**, denoted by $\hat{y}$.
